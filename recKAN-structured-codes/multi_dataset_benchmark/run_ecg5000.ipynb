# %% [markdown]
# # Run Benchmark — ECG5000

# %%
# !pip install aeon -q

import sys

if '-f' in sys.argv:
    try:
        idx = sys.argv.index('-f')
        del sys.argv[idx:idx+2]
    except:
        pass

sys.argv = ['script.py', '--datasets', 'ECG5000']

print("ECG5000...")
main()
